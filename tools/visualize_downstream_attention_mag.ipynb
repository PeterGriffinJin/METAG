# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %matplotlib inline

# %%
sns.set(font_scale=2)

# %% [markdown]
# ## year prediction

# %%
geology = [[7.1501e-05, 1.4185e-04, 9.6075e-05, 5.6095e-05, 3.4044e-05, 4.1843e-06,
         5.1418e-06, 1.1972e-05, 1.2167e-05, 1.6880e-05, 6.4053e-06, 7.0486e-06,
         1.7492e-05, 1.3949e-05, 2.0864e-05, 6.2110e-03, 8.1006e-03, 9.3266e-01,
         1.8688e-02, 3.3576e-02, 1.8300e-05, 2.5728e-05, 4.2312e-05, 6.2182e-05,
         1.0368e-04],
        [5.1824e-03, 3.8966e-03, 5.6254e-03, 1.6278e-02, 9.6849e-01, 1.8210e-06,
         1.1672e-06, 7.3015e-06, 5.5128e-06, 7.1254e-06, 1.4752e-07, 1.0667e-07,
         4.9518e-07, 2.9338e-07, 3.6584e-07, 3.3647e-05, 2.1179e-05, 7.5528e-05,
         7.9930e-05, 1.1032e-04, 1.4989e-05, 9.3525e-06, 4.5721e-05, 4.8765e-05,
         6.6914e-05],
        [6.9060e-04, 7.6442e-04, 7.6442e-04, 2.7961e-03, 3.9586e-03, 3.2754e-03,
         1.9673e-03, 9.4068e-01, 1.3471e-02, 3.0356e-02, 2.9266e-05, 1.9667e-05,
         8.7629e-05, 7.2860e-05, 1.1544e-04, 2.0213e-05, 1.2526e-05, 5.6384e-05,
         6.3985e-05, 1.1337e-04, 4.3507e-05, 2.4453e-05, 1.7123e-04, 1.3075e-04,
         3.1664e-04],
        [1.2804e-01, 1.2678e-02, 2.4726e-02, 1.2508e-01, 7.0310e-01, 3.7103e-05,
         2.3577e-05, 1.1461e-04, 6.4860e-05, 8.1871e-05, 1.6984e-06, 1.2670e-06,
         4.4746e-06, 2.3123e-06, 2.7193e-06, 1.4963e-04, 9.5764e-05, 2.3153e-04,
         2.0633e-04, 2.6133e-04, 2.6364e-04, 1.6084e-04, 3.5621e-03, 4.8396e-04,
         6.2751e-04],
        [1.5715e-03, 1.1123e-02, 3.7478e-03, 4.3137e-03, 5.0728e-03, 2.0017e-04,
         2.4446e-04, 4.3617e-04, 1.2889e-03, 4.6279e-03, 1.8950e-05, 2.1897e-05,
         4.0314e-05, 7.6652e-05, 2.5395e-04, 2.1274e-02, 2.7104e-02, 1.0269e-01,
         1.3981e-01, 6.6962e-01, 1.5397e-04, 1.7645e-04, 1.4013e-04, 1.0917e-03,
         4.8976e-03]]

math = [[3.5729e-02, 9.7883e-02, 2.5534e-02, 1.7618e-02, 5.4056e-02, 4.5335e-03,
         2.8095e-03, 6.9014e-01, 5.4056e-02, 1.0097e-02, 3.8842e-05, 2.5824e-05,
         1.3643e-04, 3.3772e-04, 8.4178e-05, 4.5101e-05, 3.0132e-05, 1.6107e-04,
         6.0877e-04, 9.8030e-05, 2.1887e-04, 1.2836e-04, 1.5455e-03, 3.5515e-03,
         5.3306e-04],
        [6.9791e-03, 1.2639e-01, 4.8437e-03, 3.9533e-03, 8.3041e-03, 9.1202e-03,
         4.9877e-03, 5.5767e-01, 2.4458e-01, 2.0393e-02, 2.7429e-05, 1.6734e-05,
         8.1569e-05, 4.8430e-04, 5.9503e-05, 2.9600e-05, 1.6866e-05, 7.3980e-05,
         9.2534e-04, 6.7954e-05, 2.3020e-04, 1.0680e-04, 7.2348e-04, 9.3730e-03,
         5.5147e-04],
        [1.0594e-02, 1.3472e-01, 9.2761e-03, 5.8847e-03, 1.6601e-02, 7.8725e-03,
         4.8501e-03, 5.8980e-01, 1.9526e-01, 1.7128e-02, 3.4720e-05, 2.3038e-05,
         1.1530e-04, 5.6336e-04, 7.1869e-05, 3.0580e-05, 2.0291e-05, 9.3278e-05,
         8.7726e-04, 6.7055e-05, 1.3712e-04, 7.5392e-05, 5.2154e-04, 5.0631e-03,
         3.1824e-04],
        [9.8867e-01, 1.2664e-03, 2.3022e-03, 1.4520e-03, 4.3179e-03, 1.2067e-06,
         1.0691e-06, 4.8336e-06, 2.7474e-06, 1.8754e-06, 1.1345e-07, 1.2534e-07,
         3.9599e-07, 2.7807e-07, 2.0029e-07, 4.6206e-07, 5.6724e-07, 2.9054e-06,
         1.2845e-06, 7.7608e-07, 1.8883e-06, 2.1915e-06, 1.9615e-03, 5.2893e-06,
         3.4102e-06],
        [9.0218e-01, 1.4812e-02, 1.2424e-02, 7.3612e-03, 5.9042e-02, 1.3152e-05,
         1.1085e-05, 7.6149e-05, 5.7818e-05, 2.1892e-05, 1.8170e-07, 1.9117e-07,
         7.0611e-07, 7.5460e-07, 3.3682e-07, 9.4648e-07, 1.0746e-06, 4.3213e-06,
         5.0324e-06, 1.6873e-06, 1.7313e-05, 1.7369e-05, 3.8189e-03, 9.7681e-05,
         3.3332e-05]]

# %%
geology = pd.DataFrame(np.transpose(np.array(geology)))

geology.columns = [0, 1, 2, 3, 4]

geology = geology.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
math = pd.DataFrame(np.transpose(np.array(math)))

math.columns = [0, 1, 2, 3, 4]
math = math.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=geology,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_geology_year.pdf', dpi=199,  bbox_inches='tight')

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=math,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_math_year.pdf', dpi=199,  bbox_inches='tight')

# %% [markdown]
# ## citation prediction

# %%
geology = [[1.2367e-06, 3.3748e-06, 5.5641e-06, 2.6283e-06, 2.1535e-06, 1.0643e-04,
         1.2771e-03, 3.1523e-05, 6.5956e-05, 1.4043e-05, 9.8863e-02, 7.7459e-01,
         4.5440e-02, 6.2109e-02, 1.7298e-02, 9.5391e-06, 1.1689e-04, 7.4290e-06,
         6.7116e-06, 1.3011e-06, 2.9666e-06, 4.7786e-05, 5.3189e-07, 1.8064e-06,
         2.8918e-07],
        [1.1771e-04, 1.3306e-04, 1.4730e-04, 2.8970e-04, 3.8492e-04, 5.4343e-03,
         2.7865e-03, 9.6717e-01, 1.2223e-02, 1.0702e-02, 5.5751e-05, 3.2125e-05,
         1.0039e-04, 8.9069e-05, 6.9485e-05, 8.2989e-06, 4.2552e-06, 1.3262e-05,
         1.4794e-05, 1.0511e-05, 3.2823e-05, 1.5145e-05, 6.5691e-05, 5.1562e-05,
         4.4951e-05],
        [5.8910e-07, 1.5340e-06, 2.8325e-06, 1.4524e-06, 9.8656e-07, 4.1380e-05,
         1.4966e-03, 1.7487e-05, 3.2543e-05, 8.4894e-06, 4.2880e-02, 8.8514e-01,
         2.6161e-02, 3.3070e-02, 1.0948e-02, 3.3901e-06, 1.3099e-04, 4.3022e-06,
         3.0988e-06, 7.2178e-07, 9.0886e-07, 5.1599e-05, 2.3802e-07, 7.3602e-07,
         1.4664e-07],
        [1.4587e-02, 3.6051e-02, 8.3047e-02, 5.5864e-02, 4.7226e-02, 2.4148e-01,
         1.2418e-01, 4.2478e-02, 8.0649e-02, 4.3720e-02, 6.9006e-03, 4.4663e-03,
         2.5324e-03, 3.0309e-03, 2.0329e-03, 7.9244e-02, 4.1637e-02, 1.9034e-02,
         2.6485e-02, 1.5473e-02, 1.5613e-02, 6.5814e-03, 1.3306e-03, 4.0587e-03,
         2.2946e-03],
        [7.7418e-06, 2.8098e-05, 2.4507e-05, 1.4239e-05, 1.3067e-05, 4.7431e-04,
         2.0513e-03, 1.8180e-04, 5.1386e-04, 1.5641e-04, 1.5256e-01, 5.1509e-01,
         1.0547e-01, 1.6208e-01, 6.0802e-02, 5.2699e-05, 2.3297e-04, 4.7239e-05,
         6.6358e-05, 1.8644e-05, 1.4865e-05, 7.4901e-05, 3.8475e-06, 1.6583e-05,
         3.8625e-06]]

math = [[4.7384e-04, 1.5605e-03, 4.9901e-04, 5.9520e-04, 9.6705e-04, 1.1067e-02,
         7.2439e-03, 9.1064e-01, 4.7144e-02, 1.7548e-02, 1.8078e-04, 1.1778e-04,
         4.2641e-04, 6.4294e-04, 2.7444e-04, 1.6509e-05, 1.0618e-05, 3.2737e-05,
         7.5634e-05, 2.5027e-05, 4.9288e-05, 2.6279e-05, 8.3638e-05, 2.2225e-04,
         7.6079e-05],
        [7.9456e-03, 3.5580e-01, 1.0054e-02, 9.2441e-03, 1.9762e-02, 1.2561e-02,
         1.4346e-02, 7.1724e-02, 4.5686e-01, 1.8241e-02, 2.3188e-04, 2.6224e-04,
         4.8445e-04, 5.3240e-03, 3.4571e-04, 8.5971e-05, 1.0350e-04, 2.2806e-04,
         3.7459e-03, 1.3873e-04, 2.1257e-04, 2.0028e-04, 3.1324e-04, 1.1460e-02,
         3.2005e-04],
        [6.0197e-04, 2.0245e-03, 5.5564e-04, 7.6393e-04, 1.1401e-03, 8.8458e-03,
         5.4818e-03, 9.1830e-01, 4.5541e-02, 1.4727e-02, 1.3962e-04, 8.6299e-05,
         3.6654e-04, 5.7665e-04, 2.1448e-04, 1.4324e-05, 8.8419e-06, 3.1624e-05,
         7.8423e-05, 2.2534e-05, 4.5122e-05, 2.3455e-05, 9.2044e-05, 2.4801e-04,
         7.0953e-05],
        [7.4419e-04, 1.9078e-03, 7.3552e-04, 1.0063e-03, 1.3502e-03, 8.6679e-03,
         4.9100e-03, 9.2839e-01, 3.6708e-02, 1.3770e-02, 1.3400e-04, 7.5876e-05,
         3.5498e-04, 4.7165e-04, 2.0415e-04, 1.3315e-05, 7.3387e-06, 2.7995e-05,
         5.9906e-05, 1.9949e-05, 4.7204e-05, 2.1318e-05, 9.5682e-05, 2.0567e-04,
         7.0724e-05],
        [7.7509e-05, 1.1730e-02, 1.1670e-04, 9.7408e-05, 2.3276e-04, 2.2478e-02,
         1.9077e-02, 4.7680e-02, 7.6055e-01, 1.7472e-02, 4.4566e-03, 3.7675e-03,
         3.5497e-03, 9.9373e-02, 3.8194e-03, 4.5387e-05, 3.6972e-05, 4.4771e-05,
         1.8362e-03, 4.0924e-05, 7.2105e-05, 4.1731e-05, 2.6474e-05, 3.3281e-03,
         5.0931e-05]]

# %%
geology = pd.DataFrame(np.transpose(np.array(geology)))


geology.columns = [0, 1, 2, 3, 4]
geology = geology.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
math = pd.DataFrame(np.transpose(np.array(math)))

math.columns = [0, 1, 2, 3, 4]
math = math.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=geology,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_geology_citation.pdf', dpi=199,  bbox_inches='tight')

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=math,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_math_citation.pdf', dpi=199,  bbox_inches='tight')

# %% [markdown]
# ## paper classification

# %%
geology = [[7.7020e-03, 6.7441e-03, 1.4474e-02, 2.5555e-01, 7.0285e-01, 6.7662e-04,
         5.3173e-04, 7.0402e-03, 9.9949e-04, 1.3635e-03, 9.3513e-05, 7.8209e-05,
         2.0167e-04, 1.0858e-04, 1.2907e-04, 9.8866e-05, 7.9596e-05, 1.4878e-04,
         1.1960e-04, 1.4633e-04, 1.4462e-04, 1.1638e-04, 1.6388e-04, 1.7754e-04,
         2.5401e-04],
        [8.6834e-03, 6.9637e-03, 1.7438e-02, 3.2904e-01, 6.1233e-01, 7.6470e-04,
         5.9352e-04, 1.9227e-02, 1.3148e-03, 1.7283e-03, 7.3601e-05, 6.1376e-05,
         1.9016e-04, 9.4691e-05, 1.0772e-04, 7.7738e-05, 6.2160e-05, 1.5058e-04,
         1.0512e-04, 1.2194e-04, 1.2867e-04, 1.0563e-04, 2.0248e-04, 1.8413e-04,
         2.4820e-04],
        [8.0874e-03, 6.9582e-03, 1.4644e-02, 3.3855e-01, 6.1785e-01, 6.9097e-04,
         5.4169e-04, 8.2148e-03, 9.7111e-04, 1.3582e-03, 1.0062e-04, 8.5645e-05,
         2.1668e-04, 1.1313e-04, 1.3619e-04, 1.0483e-04, 8.3335e-05, 1.5201e-04,
         1.1856e-04, 1.4350e-04, 1.5017e-04, 1.2125e-04, 1.7369e-04, 1.7651e-04,
         2.5222e-04],
        [7.5571e-03, 6.4011e-03, 1.4063e-02, 2.6432e-01, 6.9640e-01, 6.6486e-04,
         5.0407e-04, 6.0368e-03, 9.2262e-04, 1.1818e-03, 9.4205e-05, 7.7795e-05,
         2.0416e-04, 1.0530e-04, 1.1839e-04, 9.8246e-05, 7.5548e-05, 1.4463e-04,
         1.1089e-04, 1.2480e-04, 1.4135e-04, 1.0664e-04, 1.6033e-04, 1.6550e-04,
         2.1532e-04],
        [1.0650e-02, 7.5224e-03, 2.0608e-02, 3.3916e-01, 5.6578e-01, 1.0648e-03,
         7.7714e-04, 4.7729e-02, 1.9643e-03, 2.5197e-03, 7.9351e-05, 6.4261e-05,
         2.1298e-04, 1.0657e-04, 1.1739e-04, 8.5381e-05, 6.5528e-05, 1.8155e-04,
         1.2266e-04, 1.3439e-04, 1.4292e-04, 1.1234e-04, 2.9940e-04, 2.1581e-04,
         2.8139e-04]]

math = [[6.7520e-03, 3.4961e-03, 8.0026e-03, 3.1466e-02, 9.4876e-01, 7.4280e-05,
         6.8899e-05, 1.8096e-04, 8.7951e-05, 8.8382e-05, 3.0365e-05, 3.1421e-05,
         6.2825e-05, 3.6915e-05, 3.8498e-05, 5.5200e-05, 5.9511e-05, 9.0743e-05,
         6.6098e-05, 6.6649e-05, 7.8954e-05, 8.6884e-05, 1.2069e-04, 9.1723e-05,
         1.0389e-04],
        [7.2696e-03, 3.8911e-03, 9.8590e-03, 4.0074e-02, 9.3737e-01, 7.3963e-05,
         7.0061e-05, 1.8937e-04, 9.0533e-05, 8.9260e-05, 3.1257e-05, 3.3078e-05,
         6.8405e-05, 3.8635e-05, 3.9397e-05, 5.5072e-05, 6.1437e-05, 9.4508e-05,
         6.7872e-05, 6.7344e-05, 7.5939e-05, 8.7022e-05, 1.1297e-04, 9.1021e-05,
         1.0021e-04],
        [7.9103e-03, 3.9389e-03, 9.0162e-03, 4.8837e-02, 9.2871e-01, 8.0364e-05,
         7.3602e-05, 1.9873e-04, 9.1153e-05, 9.4600e-05, 3.2170e-05, 3.2709e-05,
         6.7673e-05, 3.7100e-05, 3.8880e-05, 5.8538e-05, 6.2863e-05, 9.6042e-05,
         6.6429e-05, 6.9109e-05, 8.2956e-05, 9.2273e-05, 1.2251e-04, 9.0709e-05,
         1.0369e-04],
        [8.2051e-03, 4.0698e-03, 1.0112e-02, 6.5683e-02, 9.1027e-01, 8.7019e-05,
         7.5419e-05, 2.0348e-04, 9.5059e-05, 9.0884e-05, 3.6435e-05, 3.5039e-05,
         7.5162e-05, 4.0527e-05, 4.1085e-05, 6.5782e-05, 6.5142e-05, 1.0354e-04,
         7.1615e-05, 6.9887e-05, 9.2090e-05, 9.2225e-05, 1.2413e-04, 9.5385e-05,
         1.0174e-04],
        [7.0984e-03, 3.5623e-03, 9.3489e-03, 3.5978e-02, 9.4250e-01, 7.2221e-05,
         6.8846e-05, 1.8694e-04, 8.6691e-05, 8.5890e-05, 3.0700e-05, 3.2904e-05,
         6.7680e-05, 3.7249e-05, 3.8960e-05, 5.4462e-05, 6.0166e-05, 9.3187e-05,
         6.4455e-05, 6.4644e-05, 7.6579e-05, 8.6142e-05, 1.1734e-04, 8.7200e-05,
         9.8546e-05]]

# %%
geology = pd.DataFrame(np.transpose(np.array(geology)))

geology.columns = [0, 1, 2, 3, 4]
geology = geology.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
math = pd.DataFrame(np.transpose(np.array(math)))

math.columns = [0, 1, 2, 3, 4]
math = math.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=geology,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_geology_class.pdf', dpi=199,  bbox_inches='tight')

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=math,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_math_class.pdf', dpi=199,  bbox_inches='tight')

# %% [markdown]
# ## paper recommendation

# %%
geology = [[8.6014e-02, 2.5277e-02, 4.2002e-02, 3.7803e-01, 4.4543e-01, 4.3301e-04,
         3.9813e-04, 1.3150e-03, 6.1905e-04, 6.9635e-04, 2.7163e-04, 2.5919e-04,
         5.1446e-04, 3.3608e-04, 3.4844e-04, 6.0206e-04, 5.5437e-04, 8.2755e-04,
         7.8965e-04, 8.2171e-04, 1.6049e-03, 1.5199e-03, 6.4098e-03, 2.2967e-03,
         2.6267e-03],
        [4.9616e-02, 2.0161e-03, 2.2868e-03, 3.0030e-03, 2.7828e-03, 1.9914e-04,
         2.2565e-04, 5.8932e-04, 3.0321e-04, 3.2490e-04, 1.4142e-04, 1.6214e-04,
         2.8124e-04, 2.0198e-04, 1.9548e-04, 2.0788e-04, 2.4880e-04, 4.0592e-04,
         3.1667e-04, 3.1176e-04, 1.1201e-02, 1.5014e-02, 8.6245e-01, 2.2805e-02,
         2.4706e-02],
        [1.0006e-01, 4.4831e-03, 4.9333e-03, 8.6076e-03, 7.6558e-03, 2.9656e-04,
         3.1615e-04, 9.0271e-04, 4.2604e-04, 4.7482e-04, 2.2060e-04, 2.4394e-04,
         4.1638e-04, 2.9772e-04, 2.9511e-04, 3.7415e-04, 4.1476e-04, 6.3498e-04,
         5.2764e-04, 5.1832e-04, 1.3254e-02, 1.6239e-02, 7.8704e-01, 2.4283e-02,
         2.7089e-02],
        [5.5145e-02, 2.0606e-02, 3.5604e-02, 4.1067e-01, 4.6172e-01, 4.3292e-04,
         3.7338e-04, 1.2294e-03, 5.6643e-04, 6.1096e-04, 2.6425e-04, 2.4249e-04,
         4.9756e-04, 3.0684e-04, 3.0654e-04, 5.3420e-04, 4.5414e-04, 6.8911e-04,
         6.3005e-04, 6.1276e-04, 1.1518e-03, 9.8446e-04, 3.3020e-03, 1.4840e-03,
         1.5797e-03],
        [2.7235e-01, 3.5725e-02, 6.3811e-02, 2.5188e-01, 2.8766e-01, 6.6723e-04,
         6.6268e-04, 2.0721e-03, 1.0294e-03, 1.0833e-03, 4.4534e-04, 4.6263e-04,
         8.8264e-04, 5.9055e-04, 5.8424e-04, 9.8177e-04, 1.0031e-03, 1.5960e-03,
         1.4283e-03, 1.3876e-03, 4.2232e-03, 4.4999e-03, 5.0478e-02, 7.0829e-03,
         7.4083e-03]]

math = [[1.6663e-01, 1.1722e-02, 1.0958e-02, 1.4348e-02, 1.7443e-02, 1.4961e-03,
         1.2716e-03, 3.0389e-03, 2.1166e-03, 2.0671e-03, 9.0215e-04, 8.0239e-04,
         1.5123e-03, 1.2164e-03, 1.1940e-03, 8.1423e-04, 7.3560e-04, 1.1477e-03,
         1.1494e-03, 1.1371e-03, 2.6211e-02, 2.6365e-02, 6.2640e-01, 4.0123e-02,
         3.9194e-02],
        [1.2410e-01, 9.5136e-03, 8.5697e-03, 9.8252e-03, 1.0993e-02, 1.3487e-03,
         1.1712e-03, 2.7622e-03, 1.9187e-03, 1.8333e-03, 8.4068e-04, 7.6135e-04,
         1.4259e-03, 1.1252e-03, 1.0795e-03, 7.3720e-04, 6.8247e-04, 1.0371e-03,
         1.0401e-03, 1.0101e-03, 2.9304e-02, 3.0710e-02, 6.7088e-01, 4.4946e-02,
         4.2388e-02],
        [1.4309e-01, 9.7754e-03, 8.4105e-03, 1.1208e-02, 1.2527e-02, 1.4523e-03,
         1.2229e-03, 2.9412e-03, 1.9576e-03, 1.9550e-03, 8.7016e-04, 7.5971e-04,
         1.4654e-03, 1.1140e-03, 1.0893e-03, 7.5675e-04, 6.7768e-04, 1.0298e-03,
         1.0050e-03, 1.0134e-03, 2.7631e-02, 2.8176e-02, 6.6163e-01, 3.9579e-02,
         3.8662e-02],
        [1.9418e-01, 1.3124e-02, 1.2845e-02, 1.7471e-02, 1.9114e-02, 1.5526e-03,
         1.2607e-03, 3.0606e-03, 2.1071e-03, 1.8686e-03, 9.1963e-04, 7.7290e-04,
         1.5621e-03, 1.1895e-03, 1.0878e-03, 8.7410e-04, 7.3967e-04, 1.2018e-03,
         1.1694e-03, 1.0595e-03, 2.6537e-02, 2.4783e-02, 6.0044e-01, 3.7864e-02,
         3.3219e-02],
        [1.5058e-01, 9.3852e-03, 9.9321e-03, 1.1189e-02, 1.3496e-02, 1.2851e-03,
         1.1269e-03, 2.7947e-03, 1.7725e-03, 1.7589e-03, 8.1329e-04, 7.5034e-04,
         1.4330e-03, 1.0612e-03, 1.0711e-03, 7.2089e-04, 6.6867e-04, 1.0576e-03,
         9.6769e-04, 9.8006e-04, 2.5462e-02, 2.6424e-02, 6.6182e-01, 3.6615e-02,
         3.6830e-02]]

# %%
geology = pd.DataFrame(np.transpose(np.array(geology)))

geology.columns = [0, 1, 2, 3, 4]
geology = geology.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
math = pd.DataFrame(np.transpose(np.array(math)))

math.columns = [0, 1, 2, 3, 4]
math = math.rename(index={0:' ',1:' ',2:'pp',3:' ',4:' ',
                               5:' ',6:' ',7:'pap',8:' ',9:' ',
                               10:' ',11:' ',12:'pvp',13:' ',14:' ',
                               15:' ',16:' ',17:'prp',18:' ',19:' ',
                               20:' ',21:' ',22:'pcp',23:' ',24:' '})

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=geology,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_geology_rec.pdf', dpi=199,  bbox_inches='tight')

# %%
from matplotlib import ticker

f, ax= plt.subplots(figsize = (20, 20))
sns.set_context({"figure.figsize":(20,20)})
chart = sns.heatmap(data=math,square=True,ax = ax) 

ax.set_xlabel('attention id',fontsize=18)
ax.set_ylabel('Source Relation',fontsize=20)
ax.tick_params(axis='x', labelsize=20)
ax.tick_params(axis='y', labelsize=20)

plt.savefig('attention_map/att_math_rec.pdf', dpi=199,  bbox_inches='tight')
